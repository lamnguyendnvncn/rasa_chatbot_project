# %%
import pandas as pd
df=pd.read_csv('Indiana Grand Standard Candidate Care Knowledge Base 1 - Default.csv')
df.head()
# Out:
#                                Intent  \
# 0                            Benefits
# 1                Benefits_Eligibility
# 2                 Benefits_Enrollment
# 3                  Benefits_Insurance
# 4  Benefits_Insurance_AccidentalDeath
#
#                                          Web Message Type Title Description  \
# 0  At Paradox, we provide a full range of benefit...  NaN   NaN         NaN
# 1  At Paradox, we provide a full range of benefit...  NaN   NaN         NaN
# 2  Eligibility waiting period for our benefits is...  NaN   NaN         NaN
# 3                                                NaN  NaN   NaN         NaN
# 4                                                NaN  NaN   NaN         NaN
#
#   Text  Media  URL State
# 0  NaN    NaN  NaN   NaN
# 1  NaN    NaN  NaN   NaN
# 2  NaN    NaN  NaN   NaN
# 3  NaN    NaN  NaN   NaN
# 4  NaN    NaN  NaN   NaN

# %%
with open('domain.yml','w') as f:
    for i in df['Intent']:
        f.write("  - "+i+"\n")

# %%
df
# Out:
#                                  Intent  \
# 0                              Benefits
# 1                  Benefits_Eligibility
# 2                   Benefits_Enrollment
# 3                    Benefits_Insurance
# 4    Benefits_Insurance_AccidentalDeath
# ..                                  ...
# 591         Paradox_Technology_Facebook
# 592               Paradox_Technology_ML
# 593              Paradox_Technology_NLP
# 594           Paradox_Technology_Python
# 595            Paradox_Technology_Stack
#
#                                            Web Message Type Title Description  \
# 0    At Paradox, we provide a full range of benefit...  NaN   NaN         NaN
# 1    At Paradox, we provide a full range of benefit...  NaN   NaN         NaN
# 2    Eligibility waiting period for our benefits is...  NaN   NaN         NaN
# 3                                                  NaN  NaN   NaN         NaN
# 4                                                  NaN  NaN   NaN         NaN
# ...

# %%
df['Web Message'].isna().sum()
# Out:
# 34

# %%
with open('responses.yml',"w") as f:
    for i in range(len(df)):
        f.write("  "+"utter_"+df['Intent'][i]+":\n")
        f.write("  - "+"text: "+'"'+str(df['Web Message'][i])+'"'+"\n\n")
